# %% [markdown]
# <a href="https://colab.research.google.com/github/subhashchandra630/Machine-Learning/blob/main/KNN_classification_on_heart_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-1be9090a-3e99-458c-93dc-5d35d8504f72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1be9090a-3e99-458c-93dc-5d35d8504f72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
path="heart.csv"
df=pd.read_csv(path)
df.head()
# Out:
#    age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63       1   3       145   233    1        0      150      0      2.3
# 1   37       1   2       130   250    0        1      187      0      3.5
# 2   41       0   1       130   204    0        0      172      0      1.4
# 3   56       1   1       120   236    0        1      178      0      0.8
# 4   57       0   0       120   354    0        1      163      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1

# %%
X=df.drop("target",1)
y=df["target"]
# Out:
# <ipython-input-4-292ca2d14225>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X=df.drop("target",1)

# %%
corr=df.corr()
cor_target = abs(corr["target"])
relevant_features = cor_target[cor_target>=0.35]
relevant_features
# Out:
# cp         0.433798
# thalach    0.421741
# exang      0.436757
# oldpeak    0.430696
# ca         0.391724
# target     1.000000
# Name: target, dtype: float64

# %%
X_new = df[['cp','thalach','exang','oldpeak','slope','ca']]
X_new
# Out:
#      cp  thalach  exang  oldpeak  slope  ca
# 0     3      150      0      2.3      0   0
# 1     2      187      0      3.5      0   0
# 2     1      172      0      1.4      2   0
# 3     1      178      0      0.8      2   0
# 4     0      163      1      0.6      2   0
# ..   ..      ...    ...      ...    ...  ..
# 298   0      123      1      0.2      1   0
# 299   3      132      0      1.2      1   0
# 300   0      141      0      3.4      1   2
# 301   0      115      1      1.2      1   1
# 302   1      174      0      0.0      1   1
#
# [303 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_new,y,test_size=0.3)
print('Train set',X_train.shape,y_train.shape)
print('Test set',X_test.shape,y_test.shape)
# Out:
# Train set (212, 6) (212,)
# Test set (91, 6) (91,)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k=3
neigh=KNeighborsClassifier(n_neighbors=k).fit(X_train,y_train)
neigh
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
from sklearn import metrics

# %%
yhat=neigh.predict(X_test)

# %%
print("Train set Accuracy:",metrics.accuracy_score(y_train,neigh.predict(X_train)))
print("Train set Accuracy:",metrics.accuracy_score(y_test,yhat))
# Out:
# Train set Accuracy: 0.839622641509434
# Train set Accuracy: 0.6703296703296703
